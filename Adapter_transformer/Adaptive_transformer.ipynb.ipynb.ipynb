# %%
# !pip install -q -U bitsandbytes
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q -U git+https://github.com/huggingface/accelerate.git
# !pip install -q datasets
# !pip install -U adapter-transformers
! pip install evaluate
#!pip install -U --user neptune transformers datasets evaluate torch scipy scikit-learn numpy
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 MB 8.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 75.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.6 MB/s eta 0:00:00
#   Building wheel for transformers (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 4.7 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for accelerate (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 17.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 15.6 MB/s eta 0:00:00
# Collecting adapter-transformers
#   Downloading adapter_transformers-3.2.1-py3-none-any.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 40.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from adapter-transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from adapter-transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from adapter-transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from adapter-transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from adapter-transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from adapter-transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from adapter-transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from adapter-transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from adapter-transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->adapter-transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->adapter-transformers) (4.6.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->adapter-transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->adapter-transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->adapter-transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->adapter-transformers) (3.4)
# Installing collected packages: adapter-transformers
# Successfully installed adapter-transformers-3.2.1
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.22.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.65.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.16.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (23.1)
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (9.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.8.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.6.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2022.7.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Installing collected packages: responses, evaluate
# Successfully installed evaluate-0.4.0 responses-0.18.0

# %%
import torch
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer, TrainerCallback, AutoModelForCausalLM, AutoModelForSeq2SeqLM, AdapterTrainer, EvalPrediction
from datasets import load_dataset, concatenate_datasets, load_from_disk, load_metric, Dataset, ClassLabel
import numpy as np
import pandas as pd
import os
#import neptune
#from getpass import getpass
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please run
#
# python -m bitsandbytes
#
#  and submit this information together with your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# bin /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cpu.so
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cpu.so: undefined symbol: cadam32bit_grad_fp32
# CUDA SETUP: Loading binary /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cpu.so...
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "

# %%
import os
from getpass import getpass
api_token = 'eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI2ZmViNmNiNy1hYmFiLTRhOWYtYjA3NC02NDRhYjJmZjUxODcifQ=='
project = 'dducl/Dissertation-Adapter'
os.environ["NEPTUNE_API_TOKEN"] = getpass("Enter your Neptune API token: ")
os.environ["NEPTUNE_PROJECT"] = project
# Out:
# Enter your Neptune API token: ··········

# %% [markdown]
# # Data Loading and Transformation

# %%
# Load data
df_total = pd.read_parquet('/content/drive/MyDrive/Dissertation/Data/df.parquet')

# %%
# One-shot sample
df_label_unique_sample = df_total.groupby('label_cat', group_keys=False).apply(lambda df: df.sample(1))
# Create label mapping
label = list(df_label_unique_sample['label'])
id = list(df_label_unique_sample['label_cat'])
label_to_id = dict(zip(label,id))
id_to_label = dict(zip(id,label))

# %%
# Define mapping
Mapping = ClassLabel(names= label)

# Load dataset
# Load the parquet dataset
dataset = load_dataset("parquet", data_files={'train': '/content/drive/MyDrive/Dissertation/Data/train_df.parquet', 'test': '/content/drive/MyDrive/Dissertation/Data/test_df.parquet'})
# Out:
# Downloading and preparing dataset parquet/default to /root/.cache/huggingface/datasets/parquet/default-c72183ae075bf112/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/parquet/default-c72183ae075bf112/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Rename columns to the suitable column names for modelling
test_ds = dataset['test'].remove_columns('__index_level_0__')
train_ds = dataset['train'].remove_columns('__index_level_0__')
train_ds = train_ds.rename_column("processed_text", "text")
train_ds = train_ds.rename_column("label_cat", "labels")
test_ds = test_ds.rename_column("processed_text", "text")
test_ds= test_ds.rename_column("label_cat", "labels")

# %%
from transformers import AutoAdapterModel, list_adapters
adapter_infos = list_adapters(source="ah", model_name="bert-base-uncased")
for adapter_info in adapter_infos:
    print("Id:", adapter_info.adapter_id)
    print("Model name:", adapter_info.model_name)
    print("Uploaded by:", adapter_info.username)
# Out:
# https://raw.githubusercontent.com/Adapter-Hub/Hub/master/dist/v2/all.json not found in cache or force_download set to True, downloading to /content/~/.cache/torch/adapters/tmpu1h0ekkv
# Downloading (…)ter/dist/v2/all.json:   0%|          | 0.00/12.8k [00:00<?, ?B/s]
# storing https://raw.githubusercontent.com/Adapter-Hub/Hub/master/dist/v2/all.json in cache at ~/.cache/torch/adapters/c797b993ce20003bc43c23b8485a092ae307a73e9a448e6a8733d7ef4afc3bab.34e3ac3db1913ce095c9dbfd04e08383971a5667bf115770a137d2c730a8505f
# creating metadata file for ~/.cache/torch/adapters/c797b993ce20003bc43c23b8485a092ae307a73e9a448e6a8733d7ef4afc3bab.34e3ac3db1913ce095c9dbfd04e08383971a5667bf115770a137d2c730a8505f
# Id: @ukp/bert-base-uncased-csqa_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_nli_rte_houlsby
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_nli_rte_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_sts_qqp_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased-sick_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_sts_qqp_houlsby
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_qa_squad2_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased-ner-pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_nli_multinli_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased-hellaswag_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_lingaccept_cola_houlsby
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased-siqa_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased-imdb_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_nli_qnli_houlsby
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased-winogrande_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_sts_mrpc_houlsby
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_lingaccept_cola_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_sts_sts-b_houlsby
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_sts_stackexchange_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_qa_squad1_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_sts_sts-b_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_nli_multinli_houlsby
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_sentiment_sst-2_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased-cosmosqa_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased-scitail_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_sts_mrpc_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_qa_squad2_houlsby
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_qa_squad1_houlsby
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_sentiment_sst-2_houlsby
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased-cb_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased-boolq_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased-ukpsent1_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @ukp/bert-base-uncased_nli_qnli_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: ukp
# Id: @vblagoje/bert-base-uncased-conll2003_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: vblagoje
# Id: @vblagoje/bert-base-uncased-ldc2012t13_pfeiffer
# Model name: bert-base-uncased
# Uploaded by: vblagoje

# %%
from transformers import DataCollatorWithPadding , DistilBertConfig, AutoModelForSequenceClassification, DistilBertModelWithHeads
# Function to transform and tokenize train and test data
def transform_token(train,test):
  model_name = 'distilbert-base-uncased' # Used for comparison purpose with the baseline model
  tokenizer_bert = AutoTokenizer.from_pretrained(model_name)
  # Encode the data
  def tokenize(dataset):
    return tokenizer_bert(dataset['text'], truncation=True)
  train_ds = train.map(tokenize, batched=True)
  test_ds = test.map(tokenize, batched=True)
  data_collator = DataCollatorWithPadding(tokenizer=tokenizer_bert) # Dynamic padding

  # Configuration
  config = DistilBertConfig.from_pretrained(
    model_name,
    num_labels=len(label),
)
  #Model
  model = DistilBertModelWithHeads.from_pretrained(
      model_name,
      config=config
  )
  return train_ds, test_ds, model

# %% [markdown]
# # Baseline model

# %%
# Create train, test dataset for the baseline trainiing
train_baseline,test_baseline, model_baseline =  transform_token(train_ds,test_ds)

# %%
# Add a new adapter
from transformers import AdapterConfig
model_baseline.add_adapter('baseline')
model_baseline.add_classification_head(
    "baseline",
    num_labels= len(label),
    id2label=id_to_label
  )
# Activate the adapter
model_baseline.train_adapter("baseline")
# Out:
# Adding adapter 'baseline'.
# Adding head 'baseline' with config {'head_type': 'classification', 'num_labels': 31, 'layers': 2, 'activation_function': 'tanh', 'label2id': {'Tenant_determine': 0, 'Remain_review_date': 1, 'Rent_Review_method': 2, 'Payable_period': 3, 'Rent_review_upward': 4, 'yield_up': 5, 'Full_reinstatement': 6, 'Tenant_repair_obligation': 7, 'Tenant_repair_decorate': 8, 'Structural_alteration': 9, 'non_structural_alteration': 10, 'Parties': 11, 'Premise': 12, 'Current Tenant': 13, 'Term_period': 14, 'Use': 15, 'Annual_rent': 16, 'Rent_Commence_date': 17, 'underlet_part': 18, 'underlet_whole': 19, 'Act_1954': 20, 'payable_deduction': 21, 'suspension_rent': 22, 'assignment': 23, 'Commence_date': 24, 'VAT': 25, 'Garantor': 26, 'service_proportion': 27, 'service_landlord': 28, 'uninsured_risk': 29, 'service_cap': 30}, 'use_pooler': False, 'bias': True}.

# %%
import numpy as np
from transformers import TrainingArguments, AdapterTrainer, EvalPrediction
import evaluate
# Create a function to calculate Weighted f1 scores
f1_metric = evaluate.load("f1")
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=1)
    return f1_metric.compute(predictions=predictions, references=labels, average="weighted")

# Define functions to train the adapters
def train_adapter(train,test,model,output_directory):
  training_args = TrainingArguments(
    output_dir=output_directory,
    overwrite_output_dir=True,
    learning_rate=1e-4,
    num_train_epochs=20,
    evaluation_strategy = 'epoch',
    save_strategy="epoch",
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    load_best_model_at_end=True,
    #report_to = "neptune",
    )
  tokenizer_bert = AutoTokenizer.from_pretrained('distilbert-base-uncased')
  data_collator = DataCollatorWithPadding(tokenizer=tokenizer_bert) # Dynamic padding
  trainer = AdapterTrainer(
    model=model,
    args= training_args,
    train_dataset=train,
    eval_dataset=test,
    compute_metrics=compute_metrics,
    data_collator = data_collator,
    )
  trainer.train()

# %%
# Train the baseline adapter model
train_adapter(train_baseline, test_baseline, model_baseline, '/content/drive/MyDrive/Dissertation/adapter_transformer/baseline')
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "distilbert-base-uncased",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.26.1",
#   "vocab_size": 30522
# }
#
# loading file vocab.txt from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/vocab.txt
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/tokenizer_config.json
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "distilbert-base-uncased",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.26.1",
#   "vocab_size": 30522
# }
#
# The following columns in the training set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 261
#   Num Epochs = 20
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 340
#   Number of trainable parameters = 1061695
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='340' max='340' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [340/340 10:52, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>2.541788</td>
#       <td>0.266025</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>2.335802</td>
#       <td>0.358272</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>2.139843</td>
#       <td>0.434514</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>1.972875</td>
#       <td>0.452720</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>1.835133</td>
#       <td>0.472511</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>1.727986</td>
#       <td>0.505016</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>No log</td>
#       <td>1.633218</td>
#       <td>0.538855</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>No log</td>
#       <td>1.560255</td>
#       <td>0.514468</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>No log</td>
#       <td>1.490409</td>
#       <td>0.538566</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>No log</td>
#       <td>1.429927</td>
#       <td>0.568148</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>No log</td>
#       <td>1.373689</td>
#       <td>0.600072</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>No log</td>
#       <td>1.342781</td>
#       <td>0.620851</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>No log</td>
#       <td>1.297975</td>
#       <td>0.599711</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>No log</td>
#       <td>1.272056</td>
#       <td>0.614286</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>No log</td>
#       <td>1.247215</td>
#       <td>0.648341</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>No log</td>
#       <td>1.223428</td>
#       <td>0.638961</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>No log</td>
#       <td>1.215841</td>
#       <td>0.648701</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>No log</td>
#       <td>1.197999</td>
#       <td>0.638961</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>No log</td>
#       <td>1.190256</td>
#       <td>0.648341</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>No log</td>
#       <td>1.189045</td>
#       <td>0.648341</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-17
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-17/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-17/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-17/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-17/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-17/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-17/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-34
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-34/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-34/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-34/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-34/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-34/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-34/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-51
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-51/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-51/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-51/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-51/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-51/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-51/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-68
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-68/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-68/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-68/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-68/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-68/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-68/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-85
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-85/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-85/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-85/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-85/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-85/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-85/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-102
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-102/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-102/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-102/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-102/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-102/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-102/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-119
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-119/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-119/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-119/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-119/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-119/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-119/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-136
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-136/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-136/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-136/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-136/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-136/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-136/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-153
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-153/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-153/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-153/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-153/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-153/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-153/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-170
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-170/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-170/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-170/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-170/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-170/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-170/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-187
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-187/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-187/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-187/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-187/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-187/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-187/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-204
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-204/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-204/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-204/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-204/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-204/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-204/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-221
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-221/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-221/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-221/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-221/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-221/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-221/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-238
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-238/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-238/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-238/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-238/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-238/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-238/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-255
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-255/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-255/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-255/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-255/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-255/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-255/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-272
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-272/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-272/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-272/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-272/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-272/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-272/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-289
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-289/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-289/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-289/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-289/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-289/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-289/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-306
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-306/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-306/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-306/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-306/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-306/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-306/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-323
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-323/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-323/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-323/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-323/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-323/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-323/baseline/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-340
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-340/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-340/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-340/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-340/baseline/pytorch_model_head.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-340/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-340/baseline/pytorch_model_head.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best adapter(s) from /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-340 (score: 1.1890449523925781).
# Loading module configuration from /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-340/baseline/adapter_config.json
# Overwriting existing adapter 'baseline'.
# Loading module weights from /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-340/baseline/pytorch_adapter.bin
# Loading module configuration from /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-340/baseline/head_config.json
# Overwriting existing head 'baseline'
# Adding head 'baseline' with config {'head_type': 'classification', 'num_labels': 31, 'layers': 2, 'activation_function': 'tanh', 'label2id': {'Act_1954': 20, 'Annual_rent': 16, 'Commence_date': 24, 'Current Tenant': 13, 'Full_reinstatement': 6, 'Garantor': 26, 'Parties': 11, 'Payable_period': 3, 'Premise': 12, 'Remain_review_date': 1, 'Rent_Commence_date': 17, 'Rent_Review_method': 2, 'Rent_review_upward': 4, 'Structural_alteration': 9, 'Tenant_determine': 0, 'Tenant_repair_decorate': 8, 'Tenant_repair_obligation': 7, 'Term_period': 14, 'Use': 15, 'VAT': 25, 'assignment': 23, 'non_structural_alteration': 10, 'payable_deduction': 21, 'service_cap': 30, 'service_landlord': 28, 'service_proportion': 27, 'suspension_rent': 22, 'underlet_part': 18, 'underlet_whole': 19, 'uninsured_risk': 29, 'yield_up': 5}, 'use_pooler': False, 'bias': True}.
# Loading module weights from /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/checkpoint-340/baseline/pytorch_model_head.bin
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-fe679a189a74> in <cell line: 2>()
#       1 # Train the baseline adapter model
# ----> 2 train_adapter(train_baseline, test_baseline, model_baseline, '/content/drive/MyDrive/Dissertation/adapter_transformer/baseline')
#
# <ipython-input-41-bac7ae5d7280> in train_adapter(train, test, model, output_directory)
#      34     )
#      35   trainer.train()
# ---> 36   trainer.evalaute()
#
# AttributeError: 'AdapterTrainer' object has no attribute 'evalaute'

# %%
# Save the adapter
model_baseline.save_adapter("/content/drive/MyDrive/Dissertation/adapter_transformer/baseline", "baseline")
# Out:
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/pytorch_model_head.bin

# %% [markdown]
# # Adapter fusion
# As the previous baseline adapter performs not too well, let us examine whether use existing adpater and fusion will help to enhance the performance of the model

# %%
train_fusion, test_fusion, model_fusion = transform_token(train_ds,test_ds)
# Out:
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "distilbert-base-uncased",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.26.1",
#   "vocab_size": 30522
# }
#
# loading file vocab.txt from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/vocab.txt
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/tokenizer_config.json
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "distilbert-base-uncased",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.26.1",
#   "vocab_size": 30522
# }
#
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/parquet/default-c72183ae075bf112/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-e0e1612d90adaa62.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/parquet/default-c72183ae075bf112/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7/cache-34131646e07db14e.arrow
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/config.json
# Model config DistilBertConfig {
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6",
#     "7": "LABEL_7",
#     "8": "LABEL_8",
#     "9": "LABEL_9",
#     "10": "LABEL_10",
#     "11": "LABEL_11",
#     "12": "LABEL_12",
#     "13": "LABEL_13",
#     "14": "LABEL_14",
#     "15": "LABEL_15",
#     "16": "LABEL_16",
#     "17": "LABEL_17",
#     "18": "LABEL_18",
#     "19": "LABEL_19",
#     "20": "LABEL_20",
#     "21": "LABEL_21",
#     "22": "LABEL_22",
#     "23": "LABEL_23",
#     "24": "LABEL_24",
#     "25": "LABEL_25",
#     "26": "LABEL_26",
#     "27": "LABEL_27",
#     "28": "LABEL_28",
#     "29": "LABEL_29",
#     "30": "LABEL_30"
#   },
#   "initializer_range": 0.02,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_10": 10,
#     "LABEL_11": 11,
#     "LABEL_12": 12,
#     "LABEL_13": 13,
#     "LABEL_14": 14,
#     "LABEL_15": 15,
#     "LABEL_16": 16,
#     "LABEL_17": 17,
#     "LABEL_18": 18,
#     "LABEL_19": 19,
#     "LABEL_2": 2,
#     "LABEL_20": 20,
#     "LABEL_21": 21,
#     "LABEL_22": 22,
#     "LABEL_23": 23,
#     "LABEL_24": 24,
#     "LABEL_25": 25,
#     "LABEL_26": 26,
#     "LABEL_27": 27,
#     "LABEL_28": 28,
#     "LABEL_29": 29,
#     "LABEL_3": 3,
#     "LABEL_30": 30,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6,
#     "LABEL_7": 7,
#     "LABEL_8": 8,
#     "LABEL_9": 9
#   },
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.26.1",
#   "vocab_size": 30522
# }
#
# /usr/local/lib/python3.10/dist-packages/transformers/adapters/models/distilbert/adapter_model.py:277: FutureWarning: This class has been renamed to `DistilBertAdapterModel` in v3. Please use the new class instead as this class might be removed in a future version.
#   warnings.warn(
# loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/model.safetensors
# /usr/local/lib/python3.10/dist-packages/transformers/adapters/models/distilbert/adapter_model.py:255: FutureWarning: This class has been renamed to `DistilBertAdapterModel` in v3. Please use the new class instead as this class might be removed in a future version.
#   warnings.warn(
# Generate config GenerationConfig {
#   "pad_token_id": 0,
#   "transformers_version": "4.26.1"
# }
#
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModelWithHeads: ['vocab_layer_norm.weight', 'vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_transform.bias', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertModelWithHeads from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModelWithHeads from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of DistilBertModelWithHeads were initialized from the model checkpoint at distilbert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use DistilBertModelWithHeads for predictions without further training.
# Generation config file not found, using a generation config created from the model config.

# %%
# Load the pretrained adapters and a pretrained text classification adapter
model_fusion.load_adapter('/content/drive/MyDrive/Dissertation/adapter_transformer/baseline', load_as='baseline', with_head=False)
model_fusion.load_adapter("AdapterHub/bert-base-uncased-pf-multirc", load_as="multirc",source="hf",with_head=False)
# Out:
# Loading module configuration from /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/adapter_config.json
# Adding adapter 'baseline'.
# Loading module weights from /content/drive/MyDrive/Dissertation/adapter_transformer/baseline/pytorch_adapter.bin
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Loading module configuration from /root/.cache/huggingface/hub/models--AdapterHub--bert-base-uncased-pf-multirc/snapshots/734a29c11b74b21f40a0c1abc6962def7b084184/adapter_config.json
# Adding adapter 'multirc'.
# Loading module weights from /root/.cache/huggingface/hub/models--AdapterHub--bert-base-uncased-pf-multirc/snapshots/734a29c11b74b21f40a0c1abc6962def7b084184/pytorch_adapter.bin
# Some module weights could not be found in loaded weights file: transformer.layer.0.output_adapters.adapters.multirc.adapter_down.0.weight, transformer.layer.0.output_adapters.adapters.multirc.adapter_down.0.bias, transformer.layer.0.output_adapters.adapters.multirc.adapter_up.weight, transformer.layer.0.output_adapters.adapters.multirc.adapter_up.bias, transformer.layer.1.output_adapters.adapters.multirc.adapter_down.0.weight, transformer.layer.1.output_adapters.adapters.multirc.adapter_down.0.bias, transformer.layer.1.output_adapters.adapters.multirc.adapter_up.weight, transformer.layer.1.output_adapters.adapters.multirc.adapter_up.bias, transformer.layer.2.output_adapters.adapters.multirc.adapter_down.0.weight, transformer.layer.2.output_adapters.adapters.multirc.adapter_down.0.bias, transformer.layer.2.output_adapters.adapters.multirc.adapter_up.weight, transformer.layer.2.output_adapters.adapters.multirc.adapter_up.bias, transformer.layer.3.output_adapters.adapters.multirc.adapter_down.0.weight, transformer.layer.3.output_adapters.adapters.multirc.adapter_down.0.bias, transformer.layer.3.output_adapters.adapters.multirc.adapter_up.weight, transformer.layer.3.output_adapters.adapters.multirc.adapter_up.bias, transformer.layer.4.output_adapters.adapters.multirc.adapter_down.0.weight, transformer.layer.4.output_adapters.adapters.multirc.adapter_down.0.bias, transformer.layer.4.output_adapters.adapters.multirc.adapter_up.weight, transformer.layer.4.output_adapters.adapters.multirc.adapter_up.bias, transformer.layer.5.output_adapters.adapters.multirc.adapter_down.0.weight, transformer.layer.5.output_adapters.adapters.multirc.adapter_down.0.bias, transformer.layer.5.output_adapters.adapters.multirc.adapter_up.weight, transformer.layer.5.output_adapters.adapters.multirc.adapter_up.bias
# Some weights of the state_dict could not be loaded into model: bert.encoder.layer.0.output.adapters.multirc.adapter_down.0.weight, bert.encoder.layer.0.output.adapters.multirc.adapter_down.0.bias, bert.encoder.layer.0.output.adapters.multirc.adapter_up.weight, bert.encoder.layer.0.output.adapters.multirc.adapter_up.bias, bert.encoder.layer.1.output.adapters.multirc.adapter_down.0.weight, bert.encoder.layer.1.output.adapters.multirc.adapter_down.0.bias, bert.encoder.layer.1.output.adapters.multirc.adapter_up.weight, bert.encoder.layer.1.output.adapters.multirc.adapter_up.bias, bert.encoder.layer.2.output.adapters.multirc.adapter_down.0.weight, bert.encoder.layer.2.output.adapters.multirc.adapter_down.0.bias, bert.encoder.layer.2.output.adapters.multirc.adapter_up.weight, bert.encoder.layer.2.output.adapters.multirc.adapter_up.bias, bert.encoder.layer.3.output.adapters.multirc.adapter_down.0.weight, bert.encoder.layer.3.output.adapters.multirc.adapter_down.0.bias, bert.encoder.layer.3.output.adapters.multirc.adapter_up.weight, bert.encoder.layer.3.output.adapters.multirc.adapter_up.bias, bert.encoder.layer.4.output.adapters.multirc.adapter_down.0.weight, bert.encoder.layer.4.output.adapters.multirc.adapter_down.0.bias, bert.encoder.layer.4.output.adapters.multirc.adapter_up.weight, bert.encoder.layer.4.output.adapters.multirc.adapter_up.bias, bert.encoder.layer.5.output.adapters.multirc.adapter_down.0.weight, bert.encoder.layer.5.output.adapters.multirc.adapter_down.0.bias, bert.encoder.layer.5.output.adapters.multirc.adapter_up.weight, bert.encoder.layer.5.output.adapters.multirc.adapter_up.bias, bert.encoder.layer.6.output.adapters.multirc.adapter_down.0.weight, bert.encoder.layer.6.output.adapters.multirc.adapter_down.0.bias, bert.encoder.layer.6.output.adapters.multirc.adapter_up.weight, bert.encoder.layer.6.output.adapters.multirc.adapter_up.bias, bert.encoder.layer.7.output.adapters.multirc.adapter_down.0.weight, bert.encoder.layer.7.output.adapters.multirc.adapter_down.0.bias, bert.encoder.layer.7.output.adapters.multirc.adapter_up.weight, bert.encoder.layer.7.output.adapters.multirc.adapter_up.bias, bert.encoder.layer.8.output.adapters.multirc.adapter_down.0.weight, bert.encoder.layer.8.output.adapters.multirc.adapter_down.0.bias, bert.encoder.layer.8.output.adapters.multirc.adapter_up.weight, bert.encoder.layer.8.output.adapters.multirc.adapter_up.bias, bert.encoder.layer.9.output.adapters.multirc.adapter_down.0.weight, bert.encoder.layer.9.output.adapters.multirc.adapter_down.0.bias, bert.encoder.layer.9.output.adapters.multirc.adapter_up.weight, bert.encoder.layer.9.output.adapters.multirc.adapter_up.bias, bert.encoder.layer.10.output.adapters.multirc.adapter_down.0.weight, bert.encoder.layer.10.output.adapters.multirc.adapter_down.0.bias, bert.encoder.layer.10.output.adapters.multirc.adapter_up.weight, bert.encoder.layer.10.output.adapters.multirc.adapter_up.bias, bert.encoder.layer.11.output.adapters.multirc.adapter_down.0.weight, bert.encoder.layer.11.output.adapters.multirc.adapter_down.0.bias, bert.encoder.layer.11.output.adapters.multirc.adapter_up.weight, bert.encoder.layer.11.output.adapters.multirc.adapter_up.bias
# 'multirc'

# %%
# Add a fusion layer for all loaded adapters
from transformers.adapters.composition import Fuse
model_fusion.add_adapter_fusion(Fuse("multirc", "baseline"))
model_fusion.set_active_adapters(Fuse("multirc", "baseline"))
# Add a classification head for our target task
model_fusion.add_classification_head(
    "Fusion",
    num_labels= len(label),
    id2label=id_to_label
  )
# Out:
# Adding AdapterFusion 'multirc,baseline'.
# Could not identify valid prediction head(s) from setup 'Fuse[multirc, baseline]'.
# Adding head 'Fusion' with config {'head_type': 'classification', 'num_labels': 31, 'layers': 2, 'activation_function': 'tanh', 'label2id': {'Tenant_determine': 0, 'Remain_review_date': 1, 'Rent_Review_method': 2, 'Payable_period': 3, 'Rent_review_upward': 4, 'yield_up': 5, 'Full_reinstatement': 6, 'Tenant_repair_obligation': 7, 'Tenant_repair_decorate': 8, 'Structural_alteration': 9, 'non_structural_alteration': 10, 'Parties': 11, 'Premise': 12, 'Current Tenant': 13, 'Term_period': 14, 'Use': 15, 'Annual_rent': 16, 'Rent_Commence_date': 17, 'underlet_part': 18, 'underlet_whole': 19, 'Act_1954': 20, 'payable_deduction': 21, 'suspension_rent': 22, 'assignment': 23, 'Commence_date': 24, 'VAT': 25, 'Garantor': 26, 'service_proportion': 27, 'service_landlord': 28, 'uninsured_risk': 29, 'service_cap': 30}, 'use_pooler': False, 'bias': True}.

# %%
# Unfreeze and activate fusion setup
adapter_setup = Fuse("multirc", "baseline")
model_fusion.train_adapter_fusion(adapter_setup)

# %%
# Train the baseline adapter model
train_adapter(train_fusion, test_fusion, model_fusion, '/content/drive/MyDrive/Dissertation/adapter_transformer/fusion')
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "distilbert-base-uncased",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.26.1",
#   "vocab_size": 30522
# }
#
# loading file vocab.txt from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/vocab.txt
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/tokenizer_config.json
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "distilbert-base-uncased",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.26.1",
#   "vocab_size": 30522
# }
#
# The following columns in the training set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 261
#   Num Epochs = 20
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 340
#   Number of trainable parameters = 11240479
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='340' max='340' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [340/340 18:17, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>2.865789</td>
#       <td>0.182017</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>2.450839</td>
#       <td>0.362809</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>2.134604</td>
#       <td>0.408740</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>1.933393</td>
#       <td>0.522331</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>1.752343</td>
#       <td>0.531738</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>1.626775</td>
#       <td>0.532297</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>No log</td>
#       <td>1.503656</td>
#       <td>0.596366</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>No log</td>
#       <td>1.437760</td>
#       <td>0.563025</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>No log</td>
#       <td>1.373213</td>
#       <td>0.590017</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>No log</td>
#       <td>1.289431</td>
#       <td>0.649278</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>No log</td>
#       <td>1.250144</td>
#       <td>0.608802</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>No log</td>
#       <td>1.201292</td>
#       <td>0.663564</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>No log</td>
#       <td>1.181241</td>
#       <td>0.645796</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>No log</td>
#       <td>1.153234</td>
#       <td>0.659307</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>No log</td>
#       <td>1.118608</td>
#       <td>0.677489</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>No log</td>
#       <td>1.109959</td>
#       <td>0.680736</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>No log</td>
#       <td>1.100156</td>
#       <td>0.664988</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>No log</td>
#       <td>1.080682</td>
#       <td>0.690837</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>No log</td>
#       <td>1.079565</td>
#       <td>0.690837</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>No log</td>
#       <td>1.080618</td>
#       <td>0.690837</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-17
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-17/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-17/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-17/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-17/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-17/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-17/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-17/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-17/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-34
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-34/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-34/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-34/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-34/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-34/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-34/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-34/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-34/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-51
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-51/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-51/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-51/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-51/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-51/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-51/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-51/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-51/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-68
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-68/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-68/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-68/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-68/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-68/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-68/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-68/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-68/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-85
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-85/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-85/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-85/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-85/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-85/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-85/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-85/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-85/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-102
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-102/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-102/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-102/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-102/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-102/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-102/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-102/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-102/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-119
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-119/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-119/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-119/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-119/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-119/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-119/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-119/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-119/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-136
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-136/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-136/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-136/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-136/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-136/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-136/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-136/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-136/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-153
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-153/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-153/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-153/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-153/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-153/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-153/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-153/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-153/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-170
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-170/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-170/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-170/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-170/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-170/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-170/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-170/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-170/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-187
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-187/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-187/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-187/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-187/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-187/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-187/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-187/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-187/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-204
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-204/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-204/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-204/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-204/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-204/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-204/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-204/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-204/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-221
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-221/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-221/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-221/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-221/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-221/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-221/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-221/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-221/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-238
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-238/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-238/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-238/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-238/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-238/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-238/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-238/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-238/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-255
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-255/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-255/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-255/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-255/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-255/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-255/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-255/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-255/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-272
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-272/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-272/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-272/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-272/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-272/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-272/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-272/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-272/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-289
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-289/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-289/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-289/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-289/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-289/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-289/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-289/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-289/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-306
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-306/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-306/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-306/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-306/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-306/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-306/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-306/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-306/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323/Fusion/pytorch_model_head.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertModelWithHeads.forward` and have been ignored: text. If text are not expected by `DistilBertModelWithHeads.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-340
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-340/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-340/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-340/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-340/multirc/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-340/multirc,baseline/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-340/multirc,baseline/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-340/Fusion/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-340/Fusion/pytorch_model_head.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best adapter(s) from /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323 (score: 1.0795649290084839).
# Loading module configuration from /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323/baseline/adapter_config.json
# Overwriting existing adapter 'baseline'.
# Loading module weights from /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323/baseline/pytorch_adapter.bin
# No matching prediction head found in '/content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323/baseline'
# Loading module configuration from /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323/multirc/adapter_config.json
# Overwriting existing adapter 'multirc'.
# Loading module weights from /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323/multirc/pytorch_adapter.bin
# No matching prediction head found in '/content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323/multirc'
# Loading best adapter fusion(s) from /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323 (score: 1.0795649290084839).
# Loading module configuration from /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323/multirc,baseline/adapter_fusion_config.json
# Overwriting existing adapter fusion module 'multirc,baseline'
# Loading module weights from /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323/multirc,baseline/pytorch_model_adapter_fusion.bin
# No matching prediction head found in '/content/drive/MyDrive/Dissertation/adapter_transformer/fusion/checkpoint-323/multirc,baseline'

# %%
# Save fusion adapter
#save trainer
model_fusion.save_adapter_fusion("/content/drive/MyDrive/Dissertation/adapter_transformer/fusion", "multirc,baseline")
model_fusion.save_all_adapters("/content/drive/MyDrive/Dissertation/adapter_transformer/fusionr")
# Out:
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/adapter_fusion_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusion/pytorch_model_adapter_fusion.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusionr/baseline/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusionr/baseline/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusionr/multirc/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/fusionr/multirc/pytorch_adapter.bin

# %% [markdown]
# # IA3

# %%
# Load model
model_bert_IA3 = AutoModelForSequenceClassification.from_pretrained("distilbert-base-uncased",
                                                                    num_labels=len(label),id2label=id_to_label,
                                                                    label2id = label_to_id)

# %%
from transformers.adapters import IA3Config
config = IA3Config()
model_bert_IA3.add_adapter("ia3_adapter", config=config)
'''
model_bert_ia3.add_classification_head(
    "ia3",
    num_labels= len(label),
    id2label=id_to_label
  )
  '''
model_bert_IA3.set_active_adapters("ia3_adapter")
# Out:
# Adding adapter 'ia3_adapter'.

# %%
model_bert_IA3.train_adapter('ia3_adapter')

# %%
import numpy as np
from transformers import TrainingArguments, AdapterTrainer, EvalPrediction
training_args = TrainingArguments(
    output_dir='/content/drive/MyDrive/Dissertation/adapter_transformer/IA3',
    overwrite_output_dir=True,
    learning_rate=1e-4,
    weight_decay=0.01,
    num_train_epochs=6,
    evaluation_strategy = 'epoch',
    save_strategy="epoch",
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    load_best_model_at_end=True)

trainer_IA3 = AdapterTrainer(
    model=model_bert_IA3,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=test_ds,
    data_collator=data_collator,
    tokenizer = tokenizer_bert,
    compute_metrics=compute_metrics)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
trainer_IA3.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running training *****
#   Num examples = 261
#   Num Epochs = 6
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 102
#   Number of trainable parameters = 642079
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='102' max='102' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [102/102 03:37, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>3.309322</td>
#       <td>0.032727</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>3.233877</td>
#       <td>0.032727</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>3.178425</td>
#       <td>0.032727</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>3.138346</td>
#       <td>0.032727</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>3.113499</td>
#       <td>0.032727</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>3.106144</td>
#       <td>0.032727</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-17
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-17/ia3_adapter/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-17/ia3_adapter/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-17/ia3_adapter/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-17/ia3_adapter/pytorch_model_head.bin
# tokenizer config file saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-17/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-17/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-34
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-34/ia3_adapter/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-34/ia3_adapter/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-34/ia3_adapter/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-34/ia3_adapter/pytorch_model_head.bin
# tokenizer config file saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-34/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-34/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-51
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-51/ia3_adapter/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-51/ia3_adapter/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-51/ia3_adapter/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-51/ia3_adapter/pytorch_model_head.bin
# tokenizer config file saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-51/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-51/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-68
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-68/ia3_adapter/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-68/ia3_adapter/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-68/ia3_adapter/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-68/ia3_adapter/pytorch_model_head.bin
# tokenizer config file saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-68/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-68/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-85
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-85/ia3_adapter/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-85/ia3_adapter/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-85/ia3_adapter/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-85/ia3_adapter/pytorch_model_head.bin
# tokenizer config file saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-85/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-85/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 66
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-102
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-102/ia3_adapter/adapter_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-102/ia3_adapter/pytorch_adapter.bin
# Configuration saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-102/ia3_adapter/head_config.json
# Module weights saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-102/ia3_adapter/pytorch_model_head.bin
# tokenizer config file saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-102/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-102/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best adapter(s) from /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-102 (score: 3.106144428253174).
# Loading module configuration from /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-102/ia3_adapter/adapter_config.json
# Overwriting existing adapter 'ia3_adapter'.
# Loading module weights from /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-102/ia3_adapter/pytorch_adapter.bin
# Loading module configuration from /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-102/ia3_adapter/head_config.json
# Loading module weights from /content/drive/MyDrive/Dissertation/adapter_transformer/IA3/checkpoint-102/ia3_adapter/pytorch_model_head.bin
# TrainOutput(global_step=102, training_loss=3.193887149586397, metrics={'train_runtime': 220.6254, 'train_samples_per_second': 7.098, 'train_steps_per_second': 0.462, 'total_flos': 11787713431656.0, 'train_loss': 3.193887149586397, 'epoch': 6.0})
